# %% [markdown]
# <a href="https://colab.research.google.com/github/Veroguerra/Nuevas_tecnologias_VeroGuerra/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
info_hopital = pd.read_csv('/content/drive/MyDrive/Hospital/BaseDatosVeroFinal22.csv', encoding='ISO-8859-1', sep=';')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
info_hopital
# Out:
#      Nombre    Cedula                           Hospital      Origen  Hijos  \
# 0       Ana  72486531                Hospital San Rafael       París      0
# 1    Carlos  20974358            Centro Médico del Valle  Nueva York      0
# 2     María  58632197               Clínica Santa Teresa       Tokio      1
# 3      Juan  93765482  Hospital Universitario San Martín     Londres      0
# 4     Laura  40821579    Hospital Regional de la Montaña        Roma      0
# ..      ...       ...                                ...         ...    ...
# 95   Felipe  35692148              Clínica San Sebastián       París      2
# 96  Daniela  89237541    Hospital Infantil San Francisco       Tokio      0
# 97    Simón  73561894            Centro Médico del Norte  Nueva York      0
# 98    Belén  14986327              Hospital de la Sierra      Sídney      1
# 99     Iván  58473169                Clínica San Lorenzo     Londres      0
#
#    Tomamedicamentos  Edad Diadeingreso enfermo  Unnamed: 9  Unnamed: 10  \
# 0                No    25      Viernes      No         NaN          NaN
# 1                No    40      Domingo      No         NaN          NaN
# 2                Sí    18    Miércoles      Sí         NaN          NaN
# 3                No    60       Jueves      No         NaN          NaN
# 4                Sí    35        Lunes      Sí         NaN          NaN
# ..              ...   ...          ...     ...         ...          ...
# 95               No    18      Viernes      No         NaN          NaN
# 96               No    35       Martes      No         NaN          NaN
# 97               Sí    22    Miércoles      Sí         NaN          NaN
# 98               No    50      Domingo      No         NaN          NaN
# 99               No    40       Sábado      No         NaN          NaN
#
#     Unnamed: 11
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 12 columns]

# %%
info_hopital.shape
# Out:
# (100, 12)

# %%
list(info_hopital['Hospital'].drop_duplicates().tail(5))
# Out:
# ['Clínica San Sebastián',
#  'Hospital Infantil San Francisco',
#  'Centro Médico del Norte',
#  'Hospital de la Sierra',
#  'Clínica San Lorenzo']

# %%
list(info_hopital['Edad'].drop_duplicates())
# Out:
# [25, 40, 18, 60, 35, 22, 70, 50]

# %%
list(info_hopital['Tomamedicamentos'].drop_duplicates())
# Out:
# ['No', 'Sí']
